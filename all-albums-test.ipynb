# %%
import urllib
import requests
import pandas as pd
import json
import base64

# %%
def get_session_token(SessionID, SessionKey):
    url = 'https://accounts.spotify.com/api/token'
    data = {'grant_type':'client_credentials'}
    encoded_key = base64.b64encode(str(SessionID + ":" + SessionKey).\
                                   encode("ascii"))
    header = {'Authorization': 'Basic {}'.format(encoded_key.decode("ascii"))}
    
    response = requests.post(url,
                            data = data,
                            headers = header)
    print(response.status_code)
    return response.json()['access_token']

# %%
keys = pd.read_csv(r"C:\Users\gamec\Desktop\School\Data in Emat\Client_ID,Client_Secret.txt")

# %%
access_token = get_session_token(keys['Client_ID'].iloc[0], keys['Client_Secret'].iloc[0])
# Out:
# 200

# %%
t_features_ep = 'https://api.spotify.com/v1/audio-features'
tracks_ep = 'https://api.spotify.com/v1/tracks/'
ab_tracks_ep = 'https://api.spotify.com/v1/albums/{}/tracks'
all_ab = 'https://api.spotify.com/v1/artists/{}/albums?include_groups=album&limit=20'
get_artist = 'https://api.spotify.com/v1/artists/{}'
multi_albums = 'https://api.spotify.com/v1/albums'

# %%
def api_call(endpoint_url, api_header):
    response = requests.get(endpoint_url, headers = api_header)
    print(response.status_code)
    return response.json()

# %%
session_header = {'Authorization': 'Bearer {}'.format(access_token)}

# %%
db_artist_id = '0oSGxfWSnnOXhD2fKuz2Gy'

# %%
all_ab.format(db_artist_id)
# Out:
# 'https://api.spotify.com/v1/artists/0oSGxfWSnnOXhD2fKuz2Gy/albums?include_groups=album&limit=20'

# %%
db_discog_response = api_call(all_ab.format(db_artist_id), session_header)
db_discog_response['items'][0]['id']
# Out:
# 200
# '1bqZP0fgsBTnQaYj4Dte7Z'

# %%
len(db_discog_response['items'])
# Out:
# 20

# %%
db_discog_df = pd.DataFrame(db_discog_response['items'])

# %%
db_album_ids = ','.join(db_discog_df['id'].to_list())

# %%
multi_albums + '?ids={}'.format(db_album_ids)
# Out:
# 'https://api.spotify.com/v1/albums?ids=1bqZP0fgsBTnQaYj4Dte7Z,4DsgJJ5VhknaGjd8CInuXD,4bdMmY8jiVxvSOPg2IL0u8,4pnC0csjiPwmrt3Z21tKc3,05uqcnORTiDNi7AxDIwwxV,0cqnZacz49P3vjP6bq3cdj,5ScPukrNF9Omj4gJBZ0YbV,7B4qOISwglvyQKodBynWBd,2ePgm9LMao9MIx7VWmHQoA,1HKNlpKfSTZkALqVuR2BYC,2F90unPwyFwCT7khOMGT2o,6AzBSTH7yHgFMPQRrckpHO,4SFBFUvZcwR4tSyDTXluOy,6frjpRu2P0fdF9xSS9stjY,0blyxTUATvmwqDcVM0dGt6,1m4J3FQcxlHIsPeYfCpbHA,5iZ09NPBTbpDziZcMrmjzb,6rlBjq1AZPbrX0Ivn6lS43,0vxg8oJKDu3i0bXQu7vEpi,2BW7T8PojNxH9RPq4WWa6h'

# %%
db_albums = api_call(multi_albums + '?ids={}'.format(db_album_ids), session_header)
# Out:
# 200

# %%
db_albums_df = pd.DataFrame(db_albums['albums'])
db_albums_df.iloc[0]['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/albums/1bqZP0fgsBTnQaYj4Dte7Z/tracks?offset=0&limit=50',
#  'limit': 50,
#  'next': 'https://api.spotify.com/v1/albums/1bqZP0fgsBTnQaYj4Dte7Z/tracks?offset=50&limit=50',
#  'offset': 0,
#  'previous': None,
#  'total': 67,
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0oSGxfWSnnOXhD2fKuz2Gy'},
#      'href': 'https://api.spotify.com/v1/artists/0oSGxfWSnnOXhD2fKuz2Gy',
#      'id': '0oSGxfWSnnOXhD2fKuz2Gy',
#      'name': 'David Bowie',
#      'type': 'artist',
#      'uri': 'spotify:artist:0oSGxfWSnnOXhD2fKuz2Gy'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
# ...

# %%
db_track_ids = ','.join(db_albums_df['id'].to_list())

# %%
db_track_ids
# Out:
# '1bqZP0fgsBTnQaYj4Dte7Z,4DsgJJ5VhknaGjd8CInuXD,4bdMmY8jiVxvSOPg2IL0u8,4pnC0csjiPwmrt3Z21tKc3,05uqcnORTiDNi7AxDIwwxV,0cqnZacz49P3vjP6bq3cdj,5ScPukrNF9Omj4gJBZ0YbV,7B4qOISwglvyQKodBynWBd,2ePgm9LMao9MIx7VWmHQoA,1HKNlpKfSTZkALqVuR2BYC,2F90unPwyFwCT7khOMGT2o,6AzBSTH7yHgFMPQRrckpHO,4SFBFUvZcwR4tSyDTXluOy,6frjpRu2P0fdF9xSS9stjY,0blyxTUATvmwqDcVM0dGt6,1m4J3FQcxlHIsPeYfCpbHA,5iZ09NPBTbpDziZcMrmjzb,6rlBjq1AZPbrX0Ivn6lS43,0vxg8oJKDu3i0bXQu7vEpi,2BW7T8PojNxH9RPq4WWa6h'
